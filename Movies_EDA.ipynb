# %% [markdown]
# <a href="https://colab.research.google.com/github/ArdeshnaA/Netflix_Movies/blob/main/Movies_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#To upload from local drive
from google.colab import files
uploaded = files.upload()

#to upload from google drive
from google.colab import drive
drive.mount('/content/drive')

# %%
#calling a dataset from github
url = 'https://raw.githubusercontent.com/ArdeshnaA/Movies/main/netflix_titles.csv'
data = pd.read_csv(url)

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
data.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
data.shape
# Out:
# (8807, 12)

# %%
data.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
data.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
data.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
#data['cast'].unique()
#data['country'].unique()
#data['rating'].unique()
data['release_year'].unique()
#data['listed_in'].unique()
# Out:
# array([2020, 2021, 1993, 2018, 1996, 1998, 1997, 2010, 2013, 2017, 1975,
#        1978, 1983, 1987, 2012, 2001, 2014, 2002, 2003, 2004, 2011, 2008,
#        2009, 2007, 2005, 2006, 1994, 2015, 2019, 2016, 1982, 1989, 1990,
#        1991, 1999, 1986, 1992, 1984, 1980, 1961, 2000, 1995, 1985, 1976,
#        1959, 1988, 1981, 1972, 1964, 1945, 1954, 1979, 1958, 1956, 1963,
#        1970, 1973, 1925, 1974, 1960, 1966, 1971, 1962, 1969, 1977, 1967,
#        1968, 1965, 1946, 1942, 1955, 1944, 1947, 1943])

# %%
#len(data['cast'].unique())
#len(data['director'].unique())
len(data['listed_in'].unique())
# Out:
# 514

# %%
#data['title'].value_counts()
#data['director'].value_counts()
#data['cast'].value_counts()
data['listed_in'].value_counts()
# Out:
# Dramas, International Movies                          362
# Documentaries                                         359
# Stand-Up Comedy                                       334
# Comedies, Dramas, International Movies                274
# Dramas, Independent Movies, International Movies      252
#                                                      ...
# Kids' TV, TV Action & Adventure, TV Dramas              1
# TV Comedies, TV Dramas, TV Horror                       1
# Children & Family Movies, Comedies, LGBTQ Movies        1
# Kids' TV, Spanish-Language TV Shows, Teen TV Shows      1
# Cult Movies, Dramas, Thrillers                          1
# Name: listed_in, Length: 514, dtype: int64

# %%
documentaries_category = data.loc[data['listed_in'].str.contains("Documentaries", case=False)]

# %%
documentaries_category.head()
# Out:
#    show_id   type                                              title  \
# 0       s1  Movie                               Dick Johnson Is Dead
# 16     s17  Movie  Europe's Most Dangerous Man: Otto Skorzeny in ...
# 45     s46  Movie                             My Heroes Were Cowboys
# 68     s69  Movie                                         Schumacher
# 88     s89  Movie           Blood Brothers: Malcolm X & Muhammad Ali
#
#                                              director  \
# 0                                     Kirsten Johnson
# 16      Pedro de Echave García, Pablo Azorín Williams
# 45                                        Tyler Greco
# 68  Hanns-Bruno Kammertöns, Vanessa Nöcker, Michae...
# 88                                      Marcus Clarke
#
#                        cast        country          date_added  release_year  \
# 0                       NaN  United States  September 25, 2021          2020
# ...

# %%
documentaries_category.tail()
# Out:
#      show_id   type                               title  \
# 8739   s8740  Movie  Why We Fight: The Battle of Russia
# 8744   s8745  Movie                            Williams
# 8746   s8747  Movie                              Winnie
# 8756   s8757  Movie                           Woodstock
# 8763   s8764  Movie     WWII: Report from the Aleutians
#
#                          director cast  \
# 8739  Frank Capra, Anatole Litvak  NaN
# 8744              Morgan Matthews  NaN
# 8746               Pascale Lamche  NaN
# 8756                Barak Goodman  NaN
# 8763                  John Huston  NaN
#
#                                          country         date_added  \
# 8739                               United States     March 31, 2017
# 8744                              United Kingdom   November 4, 2017
# 8746  France, Netherlands, South Africa, Finland  February 26, 2018
# 8756                               United States    August 13, 2019
# ...

# %%
plt.figure(figsize=(10,7))
sns.barplot(x = 'listed_in',
            y = 'release_year',
            #hue = 'listed_in',
            data = documentaries_category)
plt.xticks(rotation = 90)
plt.ylim(1940,2035)
plt.title("Documentary Released Per Year")
plt.show()

# %%
justdoc_category = data[data['listed_in'] == 'Documentaries']
dramas_inter_movies_category = data[data['listed_in'] == 'Dramas, International Movies']

# %%
#justdoc_category.head()
dramas_inter_movies_category.head()
# Out:
#     show_id   type                     title             director  \
# 12      s13  Movie              Je Suis Karl  Christian Schwochow
# 73      s74  Movie              King of Boys         Kemi Adetiba
# 190    s191  Movie                Thimmarusu    Sharan Koppisetty
# 256    s257  Movie  Nneka The Pretty Serpent           Tosin Igho
# 268    s269  Movie                   Unroyal         Moses Inwang
#
#                                                   cast  \
# 12   Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 73   Sola Sobowale, Adesua Etomi, Remilekun "Remini...
# 190             Satya Dev, Priyanka Jawalkar, Brahmaji
# 256  Idia Aisien, Ndidi Obi, Kenneth Okolie, Zack O...
# 268  Matilda Lambert, Ik Ogbonna, Prince Sontoye, B...
#
#                      country          date_added  release_year rating  \
# 12   Germany, Czech Republic  September 23, 2021          2021  TV-MA
# 73                   Nigeria  September 14, 2021          2018  TV-MA
# ...

# %%
justdoc_category.tail()
# Out:
#      show_id   type                               title  \
# 8723   s8724  Movie            What Makes a Psychopath?
# 8737   s8738  Movie          Why Are We Getting So Fat?
# 8738   s8739  Movie                            Why Knot
# 8739   s8740  Movie  Why We Fight: The Battle of Russia
# 8763   s8764  Movie     WWII: Report from the Aleutians
#
#                                     director       cast  \
# 8723                        Rebecca Harrison        NaN
# 8737  Milla Harrison-Hansley, Alicky Sussman  Giles Yeo
# 8738                            Dhruv Dhawan        NaN
# 8739             Frank Capra, Anatole Litvak        NaN
# 8763                             John Huston        NaN
#
#                                                 country        date_added  \
# 8723                                     United Kingdom  February 1, 2019
# 8737                                     United Kingdom  February 1, 2019
# ...

# %%
plt.figure(figsize=(10,7))
sns.barplot(x = 'listed_in',
            y = 'release_year',
            #hue = 'listed_in',
            #data = justdoc_category
            data = dramas_inter_movies_category)
plt.xticks(rotation = 90)
plt.ylim(1940,2025)
plt.title("Just Documentary Released Per Year")
plt.show()
